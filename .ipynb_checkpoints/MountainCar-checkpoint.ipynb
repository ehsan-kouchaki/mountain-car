# %% [markdown]
# # Control of mountain car using defferential semi-gradient Sarsa with tiling
# # by Ehsan Kouchaki

# %%
import gym
import numpy as np
env = gym.make("MountainCar-v0")
import time

# %% [markdown]
# # Tiling Code from Sutton: http://incompleteideas.net/tiles/tiles3.py-remove

# %%
basehash = hash

class IHT:
    "Structure to handle collisions"
    def __init__(self, sizeval):
        self.size = sizeval                        
        self.overfullCount = 0
        self.dictionary = {}

    def __str__(self):
        "Prepares a string for printing whenever this object is printed"
        return "Collision table:" + \
               " size:" + str(self.size) + \
               " overfullCount:" + str(self.overfullCount) + \
               " dictionary:" + str(len(self.dictionary)) + " items"

    def count (self):
        return len(self.dictionary)
    
    def fullp (self):
        return len(self.dictionary) >= self.size
    
    def getindex (self, obj, readonly=False):
        d = self.dictionary
        if obj in d: return d[obj]
        elif readonly: return None
        size = self.size
        count = self.count()
        if count >= size:
            if self.overfullCount==0: print('IHT full, starting to allow collisions')
            self.overfullCount += 1
            return basehash(obj) % self.size
        else:
            d[obj] = count
            return count

def hashcoords(coordinates, m, readonly=False):
    if type(m)==IHT: return m.getindex(tuple(coordinates), readonly)
    if type(m)==int: return basehash(tuple(coordinates)) % m
    if m==None: return coordinates

from math import floor, log
from itertools import zip_longest

def tiles (ihtORsize, numtilings, floats, ints=[], readonly=False):
    """returns num-tilings tile indices corresponding to the floats and ints"""
    qfloats = [floor(f*numtilings) for f in floats]
    Tiles = []
    for tiling in range(numtilings):
        tilingX2 = tiling*2
        coords = [tiling]
        b = tiling
        for q in qfloats:
            coords.append( (q + b) // numtilings )
            b += tilingX2
        coords.extend(ints)
        Tiles.append(hashcoords(coords, ihtORsize, readonly))
    return Tiles

# %% [markdown]
# # Train

# %%
d = 4096
W = np.zeros((d))
X = np.zeros((d))
TilingNum = 8            #number of tilings
alpha = 0.1/TilingNum    # step size
gamma = 1
q_hat = np.zeros((3))
iht=IHT(d)

stability = 0
for ep in range(500):
    state = env.reset()    
    for ac in range(3):
        feature_idx = tiles(iht, TilingNum, [TilingNum*state[0]/(0.5+1.2),
                                             TilingNum*state[1]/(0.07+0.07)], [ac])
        for i in range(len(feature_idx)):
            q_hat[ac] += W[feature_idx[i]]            
    action = np.argmax(q_hat)
    if stability > 20:
        print('\n The learning prosecc terminated in episode number: ', ep, 'step number: ', step)
        break
    step = 0        
    while True:
        step += 1
        state_prim, R, done, _ = env.step(action)        
        delta = R - q_hat[action]
        alpha_delta = alpha * delta
        
        Feature_idx = tiles(iht, TilingNum, [TilingNum*state[0]/(0.5+1.2),
                                             TilingNum*state[1]/(0.07+0.07)], [action])
        if done == True:       # if we are in terminal state
            X = np.zeros((d))
            for i in range(len(Feature_idx)):
                X[Feature_idx[i]] = 1            
            W += alpha_delta * X
            if step < 200:
                stability += 1
            else:
                stability = 0
            print(env.step(action), 'step = ', step)
            
            break
            
        q_hat = np.zeros((3))
        for ac in range(3):
            feature_idx = tiles(iht, TilingNum, [TilingNum*state_prim[0]/(0.5+1.2),
                                                 TilingNum*state_prim[1]/(0.07+0.07)], [ac])
            for i in range(len(feature_idx)):
                q_hat[ac] += W[feature_idx[i]]            
        action = np.argmax(q_hat)
        delta += gamma*np.max(q_hat)
        alpha_delta = alpha * delta
        for i in range(len(Feature_idx)):
            W[Feature_idx[i]] += alpha_delta
        state = state_prim
# Out:
# (array([-0.47607297,  0.01600545]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.46096285,  0.02175793]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.70683656,  0.02336576]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.60680268,  0.02872425]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.69157173,  0.02312489]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.63959623,  0.02941225]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.59055094,  0.02459426]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.79326211,  0.00765249]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.81003554,  0.02314804]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.42824317, -0.0298488 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.45513045,  0.03705392]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.64216857,  0.03906742]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.49913874, -0.03708997]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.84351542,  0.01694297]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.00956904,  0.00701498]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.71620153, -0.03147496]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.1234898 , -0.00295102]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.59636823, -0.04020251]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.23483297, -0.02146835]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.73457813, -0.03931934]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.53180967, -0.03207249]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.96546664,  0.02152049]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.93616788,  0.03202317]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.82806014,  0.02548101]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.00691715, -0.0185964 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.08455309, -0.02145514]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.97691566, -0.00837285]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.6783973 ,  0.03812531]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.03313852, -0.02319377]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.71828024, -0.04349948]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.0734849 ,  0.01484452]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.00654947,  0.01082802]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.45595745,  0.04030075]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.04524569,  0.02317053]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.78703268,  0.03308708]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.13214864, -0.02701462]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.07189913,  0.02087261]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.02907111,  0.01047664]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.0592485 , -0.02901799]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.83516346,  0.02414651]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.58591844, -0.04875692]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.0463353 ,  0.00575963]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.13521375, -0.02516436]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.46089098, -0.04574872]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.52540125,  0.04094876]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.54974698, -0.05197092]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.38894495, -0.03897886]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.08551919,  0.02296244]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.01761424, -0.00833582]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.11898272,  0.02044323]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.12756832, -0.00555707]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.04306134, -0.02081274]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.2804415 ,  0.04609642]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.73502765,  0.04372782]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.09862348,  0.016996  ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.25528404, -0.04001436]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.36279785, -0.0366628 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.0308151, -0.0331529]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.73092245, -0.05466422]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.15697029, -0.0329025 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.46572067,  0.04514106]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.1655358 , -0.03015623]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.82276118,  0.041939  ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.13942595,  0.01703831]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.66878899,  0.04659186]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.05995235, 0.01076548]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.00855747,  0.03715881]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.02984247, 0.02346755]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.07428505, -0.02481003]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.1475869, -0.0057949]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.38698543,  0.04920424]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.18949068, -0.04083843]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.06297876, -0.04537439]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.11781519,  0.03601401]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.00920192, -0.0178154 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.19968896, -0.01531839]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.4142441 , 0.01494298]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.03226162, -0.02695374]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.20675412, 0.00926496]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.29488479, -0.00431065]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.35854577, -0.05536871]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.13746064, -0.02133649]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.74282241, -0.04881704]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.49362289, 0.00902087]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.21277991, -0.02196661]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.1636948 , -0.00601772]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.88319194,  0.0390827 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.08111312,  0.01868384]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.05805098, -0.03295071]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.1987581,  0.0012419]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.1464136 ,  0.01670446]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.17327496, 0.01418062]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.17522403,  0.01029599]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.52780688,  0.05151889]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.90535094,  0.03944765]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52040855, 0.01498431]), -1.0, True, {}) step =  163
# (array([-0.76792163,  0.03252049]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52847373, 0.01585583]), -1.0, True, {}) step =  160
# (array([0.51153577, 0.00687073]), -1.0, True, {}) step =  182
# (array([0.34067507, 0.00040374]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.08853731,  0.04770162]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.50521705, 0.00468697]), -1.0, True, {}) step =  168
# (array([-0.93776542,  0.03172945]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.18151372,  0.00901446]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.77727026,  0.03903764]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.16304396,  0.01038743]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.17363961,  0.0075905 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.25397722,  0.04778652]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55573419, 0.03338589]), -1.0, True, {}) step =  154
# (array([-0.64486618,  0.05223158]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.21708542, -0.0276261 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.17431524, 0.03100158]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.21521146, -0.00617459]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.39068576, 0.01108593]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.27377863, 0.00378726]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.44601882, 0.02741023]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.51989799, 0.01314791]), -1.0, True, {}) step =  189
# (array([-1.11756535,  0.01974138]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.47827779, 0.01580132]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.15101593,  0.01640959]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.36095222, 0.01841515]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.2,  0. ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.17446914,  0.01104281]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.43735954, 0.02635945]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.62726034,  0.05270897]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52787142, 0.01608414]), -1.0, True, {}) step =  198
# (array([0.52481282, 0.02277028]), -1.0, True, {}) step =  191
# (array([0.08791791, 0.03270247]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53921246, 0.03077123]), -1.0, True, {}) step =  191
# (array([0.44533208, 0.01936014]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53108962, 0.02609683]), -1.0, True, {}) step =  158
# (array([0.20622576, 0.01371108]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.20571784, -0.01667975]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.29979189, 0.00866735]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.89540551,  0.04231079]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.92315983, -0.05112684]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53280945, 0.02699942]), -1.0, True, {}) step =  193
# (array([0.32773957, 0.0209881 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.19546935, -0.03511929]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52847268, 0.01520905]), -1.0, True, {}) step =  196
# (array([-0.93684343, -0.05499066]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.03067432,  0.03161584]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([ 0.37772255, -0.0093184 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.36566569, 0.02490315]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.5103687 , 0.02502172]), -1.0, True, {'TimeLimit.truncated': False}) step =  200
# (array([-0.89978392, -0.04738284]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.37511088, 0.01098689]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.99816718,  0.0344112 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.15401858,  0.01440693]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.51297362, 0.00746194]), -1.0, True, {}) step =  171
# (array([-1.18951515,  0.00475177]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.96941718,  0.03644827]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.35412846,  0.03559926]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.0996747, -0.0252284]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.18356037, -0.04720956]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54026394, 0.02935206]), -1.0, True, {}) step =  157
# (array([0.53816742, 0.02588159]), -1.0, True, {}) step =  164
# (array([0.53146893, 0.02222227]), -1.0, True, {}) step =  191
# (array([0.50746291, 0.0173554 ]), -1.0, True, {'TimeLimit.truncated': False}) step =  200
# (array([-0.70526887, -0.06243811]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.2489147 , 0.01752174]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55520985, 0.02981361]), -1.0, True, {}) step =  159
# (array([-0.2949831 , -0.04739459]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.14434169,  0.01573314]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52798409, 0.02368614]), -1.0, True, {}) step =  165
# (array([-0.26101675,  0.04789769]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.26385363,  0.0482492 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.12605951, -0.03563182]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.7061201 ,  0.04954324]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.71949087,  0.05312644]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.63433306,  0.05296624]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54372489, 0.0283092 ]), -1.0, True, {}) step =  164
# (array([0.54147477, 0.02982245]), -1.0, True, {}) step =  156
# (array([-1.11221653, -0.03971818]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.93479332, -0.05576569]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53954701, 0.02600138]), -1.0, True, {}) step =  158
# (array([-1.14238562,  0.01772074]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.18049596,  0.00976769]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54219266, 0.02395825]), -1.0, True, {}) step =  196
# (array([0.06953562, 0.04124141]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.2,  0. ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53740867, 0.02683341]), -1.0, True, {'TimeLimit.truncated': False}) step =  199
# (array([-1.08134752,  0.0266688 ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.73543775, -0.05931583]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54516197, 0.03008552]), -1.0, True, {}) step =  152
# (array([0.12756347, 0.04096401]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.2946456, 0.0336294]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55966716, 0.03402754]), -1.0, True, {}) step =  194
# (array([-0.80522354,  0.04933858]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54563775, 0.03211152]), -1.0, True, {}) step =  166
# (array([-1.08708437, -0.04320549]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.22052301,  0.05582776]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.12736342,  0.02008051]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.37963241, 0.03587126]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.41827331,  0.06054459]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55674373, 0.03675225]), -1.0, True, {}) step =  197
# (array([-0.92083332, -0.05237557]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.04125952, -0.03803937]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.23187385,  0.05671736]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55006404, 0.03223568]), -1.0, True, {}) step =  196
# (array([0.56166805, 0.03159292]), -1.0, True, {}) step =  192
# (array([0.5560648 , 0.03554504]), -1.0, True, {}) step =  196
# (array([0.55518036, 0.03197661]), -1.0, True, {}) step =  159
# (array([0.56728613, 0.03616529]), -1.0, True, {}) step =  156
# (array([0.56376018, 0.03589837]), -1.0, True, {}) step =  192
# (array([-0.93365135, -0.05060641]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52926015, 0.02877422]), -1.0, True, {}) step =  160
# (array([0.54266617, 0.03633792]), -1.0, True, {}) step =  168
# (array([0.55458757, 0.02991851]), -1.0, True, {'TimeLimit.truncated': False}) step =  200
# (array([0.5506324 , 0.03630265]), -1.0, True, {}) step =  175
# (array([0.52464153, 0.02203106]), -1.0, True, {}) step =  171
# (array([0.55074929, 0.03720608]), -1.0, True, {'TimeLimit.truncated': False}) step =  200
# (array([0.33220655, 0.01641692]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.08427259,  0.02423744]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54037401, 0.03108867]), -1.0, True, {}) step =  149
# (array([0.5262926 , 0.01407274]), -1.0, True, {}) step =  169
# (array([0.53841164, 0.03122284]), -1.0, True, {}) step =  155
# (array([0.53710999, 0.03216345]), -1.0, True, {}) step =  144
# (array([0.21740804, 0.03028491]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-1.14238562,  0.01772074]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([-0.53443245,  0.05551526]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54179634, 0.02546526]), -1.0, True, {}) step =  157
# (array([0.53285476, 0.03049876]), -1.0, True, {}) step =  148
# (array([ 0.42347766, -0.00836609]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54403894, 0.04212289]), -1.0, True, {}) step =  195
# (array([-0.17488662,  0.05509072]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.52778754, 0.0218308 ]), -1.0, True, {}) step =  164
# (array([0.54462556, 0.02487314]), -1.0, True, {}) step =  149
# (array([0.54753927, 0.03333217]), -1.0, True, {}) step =  160
# (array([0.56032829, 0.03463647]), -1.0, True, {}) step =  152
# (array([-0.84984948,  0.04555603]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53889134, 0.03728201]), -1.0, True, {}) step =  147
# (array([0.56785517, 0.03741934]), -1.0, True, {}) step =  153
# (array([0.53428712, 0.03402909]), -1.0, True, {}) step =  173
# (array([0.53799712, 0.0322373 ]), -1.0, True, {}) step =  161
# (array([0.57890581, 0.0409481 ]), -1.0, True, {}) step =  186
# (array([0.55717324, 0.03579008]), -1.0, True, {}) step =  190
# (array([0.55234433, 0.03832895]), -1.0, True, {}) step =  194
# (array([0.46147258, 0.03321162]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.57283008, 0.04133471]), -1.0, True, {}) step =  188
# (array([0.55629703, 0.03898709]), -1.0, True, {}) step =  183
# (array([0.54932548, 0.03945443]), -1.0, True, {}) step =  157
# (array([0.54300384, 0.03787109]), -1.0, True, {}) step =  193
# (array([0.5571457 , 0.03667509]), -1.0, True, {}) step =  177
# (array([0.5633736 , 0.03855522]), -1.0, True, {}) step =  159
# (array([0.53941964, 0.0356982 ]), -1.0, True, {}) step =  194
# (array([0.55650345, 0.0382461 ]), -1.0, True, {}) step =  159
# (array([0.56698412, 0.03718064]), -1.0, True, {}) step =  156
# (array([0.55825355, 0.03629754]), -1.0, True, {}) step =  148
# (array([0.55037774, 0.03593872]), -1.0, True, {}) step =  150
# (array([-0.61258144,  0.05660906]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.44495854, 0.03461822]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55116192, 0.04021746]), -1.0, True, {}) step =  184
# (array([0.5600009 , 0.03865323]), -1.0, True, {}) step =  161
# (array([0.57763161, 0.04290218]), -1.0, True, {}) step =  189
# (array([0.54083534, 0.0405793 ]), -1.0, True, {}) step =  162
# (array([0.57276325, 0.04030291]), -1.0, True, {}) step =  195
# (array([0.55456597, 0.03755062]), -1.0, True, {}) step =  164
# (array([0.54717308, 0.03677938]), -1.0, True, {}) step =  154
# (array([0.54706316, 0.03770083]), -1.0, True, {}) step =  193
# (array([0.54171226, 0.03914555]), -1.0, True, {}) step =  160
# (array([0.53771078, 0.0367989 ]), -1.0, True, {}) step =  152
# (array([0.09629846, 0.04340101]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.53438192, 0.03208766]), -1.0, True, {}) step =  152
# (array([0.53473808, 0.03359522]), -1.0, True, {}) step =  126
# (array([0.5531898 , 0.03362431]), -1.0, True, {}) step =  114
# (array([0.53280455, 0.03123376]), -1.0, True, {}) step =  159
# (array([0.53958265, 0.02485456]), -1.0, True, {}) step =  165
# (array([-1.05385678, -0.03714123]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54514183, 0.0351847 ]), -1.0, True, {}) step =  188
# (array([0.5472273 , 0.03783834]), -1.0, True, {}) step =  188
# (array([0.49325196, 0.03865389]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.57184064, 0.04249485]), -1.0, True, {}) step =  183
# (array([0.55673031, 0.0331786 ]), -1.0, True, {}) step =  184
# (array([0.55276632, 0.04010887]), -1.0, True, {}) step =  186
# (array([0.55745001, 0.04461812]), -1.0, True, {}) step =  189
# (array([0.55200215, 0.04072107]), -1.0, True, {}) step =  167
# (array([0.55419802, 0.04036594]), -1.0, True, {}) step =  154
# (array([0.54763813, 0.03933935]), -1.0, True, {}) step =  153
# (array([0.55970066, 0.04068773]), -1.0, True, {}) step =  174
# (array([0.55280615, 0.0409366 ]), -1.0, True, {}) step =  155
# (array([0.57683381, 0.04162322]), -1.0, True, {}) step =  164
# (array([-1.16010635,  0.01436279]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55708817, 0.04023278]), -1.0, True, {}) step =  181
# (array([0.25667523, 0.04115773]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.56544167, 0.03838193]), -1.0, True, {}) step =  197
# (array([0.57691182, 0.03843524]), -1.0, True, {}) step =  186
# (array([0.53250747, 0.03015949]), -1.0, True, {}) step =  116
# (array([0.55604679, 0.03893261]), -1.0, True, {}) step =  191
# (array([0.57569522, 0.04151593]), -1.0, True, {}) step =  184
# (array([0.54873412, 0.0405708 ]), -1.0, True, {}) step =  150
# (array([0.57868231, 0.04303951]), -1.0, True, {'TimeLimit.truncated': False}) step =  200
# (array([0.54042431, 0.04025011]), -1.0, True, {}) step =  155
# (array([-0.61683044, -0.06563032]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.5527714, 0.0403597]), -1.0, True, {}) step =  150
# (array([0.52508619, 0.01512815]), -1.0, True, {}) step =  135
# (array([0.54916874, 0.02889445]), -1.0, True, {}) step =  120
# (array([0.54443115, 0.04097415]), -1.0, True, {}) step =  154
# (array([0.5347047 , 0.03196927]), -1.0, True, {}) step =  155
# (array([0.57910378, 0.04155171]), -1.0, True, {}) step =  164
# (array([0.56460159, 0.04136365]), -1.0, True, {}) step =  152
# (array([0.58065171, 0.04177592]), -1.0, True, {}) step =  155
# (array([0.57476492, 0.04170097]), -1.0, True, {}) step =  163
# (array([0.55147434, 0.04118976]), -1.0, True, {}) step =  160
# (array([0.56514651, 0.03585223]), -1.0, True, {}) step =  159
# (array([0.3602476 , 0.03521353]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.5395021 , 0.02545759]), -1.0, True, {}) step =  126
# (array([0.54109177, 0.02930779]), -1.0, True, {}) step =  120
# (array([0.58145047, 0.04087188]), -1.0, True, {}) step =  157
# (array([0.56960672, 0.03943248]), -1.0, True, {}) step =  160
# (array([0.57336506, 0.04055695]), -1.0, True, {}) step =  156
# (array([0.52988074, 0.02749382]), -1.0, True, {}) step =  126
# (array([0.53926034, 0.0385588 ]), -1.0, True, {}) step =  163
# (array([0.54413009, 0.04362493]), -1.0, True, {}) step =  158
# (array([0.56092997, 0.03717703]), -1.0, True, {}) step =  155
# (array([0.55500539, 0.03579348]), -1.0, True, {}) step =  166
# (array([0.55431156, 0.04166273]), -1.0, True, {}) step =  153
# (array([0.55745501, 0.04100719]), -1.0, True, {}) step =  153
# (array([0.28348676, 0.04031137]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.54934323, 0.03111337]), -1.0, True, {}) step =  121
# (array([0.58100965, 0.04091468]), -1.0, True, {}) step =  161
# (array([0.54183753, 0.04067354]), -1.0, True, {}) step =  118
# (array([0.56209515, 0.03933686]), -1.0, True, {}) step =  162
# (array([-0.62950107,  0.054961  ]), -1.0, True, {'TimeLimit.truncated': True}) step =  200
# (array([0.55715507, 0.03501697]), -1.0, True, {}) step =  114
# (array([0.56586835, 0.0426591 ]), -1.0, True, {}) step =  171
# (array([0.57560952, 0.04329533]), -1.0, True, {}) step =  152
# (array([0.54168703, 0.03663   ]), -1.0, True, {}) step =  153
# (array([0.56115546, 0.03936916]), -1.0, True, {}) step =  174
# (array([0.55730215, 0.04255467]), -1.0, True, {}) step =  153
# (array([0.56048992, 0.0444416 ]), -1.0, True, {}) step =  159
# (array([0.55051323, 0.04226294]), -1.0, True, {}) step =  148
# (array([0.54968015, 0.04262891]), -1.0, True, {}) step =  157
# (array([0.56612869, 0.04349736]), -1.0, True, {}) step =  186
# (array([0.54350585, 0.04248045]), -1.0, True, {}) step =  157
# (array([0.56603343, 0.04362966]), -1.0, True, {}) step =  147
# (array([0.55162003, 0.04303065]), -1.0, True, {}) step =  158
# (array([0.55754   , 0.04433108]), -1.0, True, {}) step =  162
# (array([0.55178926, 0.04399651]), -1.0, True, {}) step =  185
# (array([0.58365119, 0.04423483]), -1.0, True, {}) step =  149
# (array([0.56583862, 0.04410806]), -1.0, True, {}) step =  162
# (array([0.56380135, 0.04196549]), -1.0, True, {}) step =  168
# (array([0.53533864, 0.02976952]), -1.0, True, {}) step =  120
# (array([0.56163219, 0.04331236]), -1.0, True, {}) step =  195
# (array([0.55550156, 0.04190504]), -1.0, True, {}) step =  159
#
#  The learning prosecc terminated in episode number:  345 step number:  159

# %% [markdown]
# # Test

# %%
for ep in range(20):
    state = env.reset()    
    step = 0
    while True:
        step += 1
        env.render()
        time. sleep(.01)
        state_prim, R, done, _ = env.step(action) 
        
        Feature_idx = tiles(iht, TilingNum, [TilingNum*state[0]/(0.5+1.2),
                                             TilingNum*state[1]/(0.07+0.07)], [action])
        if done == True:       # if we are in terminal state
            print('The state in episode: ', ep + 1, 'is: ', env.step(action), 'step = ', step)
            break
            
        q_hat = np.zeros((3))
        for ac in range(3):
            feature_idx = tiles(iht, TilingNum, [TilingNum*state_prim[0]/(0.5+1.2),
                                                 TilingNum*state_prim[1]/(0.07+0.07)], [ac])
            for i in range(len(feature_idx)):
                q_hat[ac] += W[feature_idx[i]]            
        action = np.argmax(q_hat)
        state = state_prim
env.close()
# Out:
# The state in episode:  1 is:  (array([0.56737123, 0.04322614]), -1.0, True, {}) step =  167
# The state in episode:  2 is:  (array([0.53519077, 0.03340791]), -1.0, True, {}) step =  121
# The state in episode:  3 is:  (array([0.5362979 , 0.02519579]), -1.0, True, {}) step =  129
# The state in episode:  4 is:  (array([0.57466205, 0.04462355]), -1.0, True, {}) step =  173
# The state in episode:  5 is:  (array([0.55847023, 0.03892359]), -1.0, True, {}) step =  170
# The state in episode:  6 is:  (array([0.57355846, 0.04337354]), -1.0, True, {}) step =  168
# The state in episode:  7 is:  (array([0.52890017, 0.02343995]), -1.0, True, {}) step =  127
# The state in episode:  8 is:  (array([0.53851369, 0.02588231]), -1.0, True, {}) step =  130
# The state in episode:  9 is:  (array([0.54497444, 0.02640838]), -1.0, True, {}) step =  128
# The state in episode:  10 is:  (array([0.5467539 , 0.02535753]), -1.0, True, {}) step =  131
# The state in episode:  11 is:  (array([0.54320241, 0.04243572]), -1.0, True, {}) step =  177
# The state in episode:  12 is:  (array([0.52479948, 0.02363463]), -1.0, True, {}) step =  132
# The state in episode:  13 is:  (array([0.53873423, 0.03057348]), -1.0, True, {}) step =  126
# The state in episode:  14 is:  (array([0.54363022, 0.03947626]), -1.0, True, {}) step =  168
# The state in episode:  15 is:  (array([0.53082271, 0.02517254]), -1.0, True, {}) step =  130
# The state in episode:  16 is:  (array([0.52407158, 0.01767365]), -1.0, True, {}) step =  138
# The state in episode:  17 is:  (array([0.52282471, 0.01757092]), -1.0, True, {}) step =  138
# The state in episode:  18 is:  (array([0.54228238, 0.03978097]), -1.0, True, {}) step =  191
# The state in episode:  19 is:  (array([0.5477539 , 0.02546622]), -1.0, True, {}) step =  131
# The state in episode:  20 is:  (array([0.53988861, 0.024451  ]), -1.0, True, {}) step =  131
